# %% [markdown]
# <a href="https://colab.research.google.com/github/ihagoSantos/general-statistics/blob/main/normal_distribuition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Distribuição Normal
#
# - Distribuição Normal para o cálculo de probabilidade P(X <= x):
#   - `norm.cdf(x, m, s)`
# - Distribuição Normal para o cálculo de probabilidade P(X > x):
#   - `norm.sf(x, m, s)
#
# onde:
# - m = média
# - s = desvio padrão
#
# ### Importante
# Para usar as funções de cálculo de probabilidade para a distribuição normal no Python é necessário importar a função norm
# ```
# from scipy.stats import norm
# ```

# %%
from scipy.stats import norm

# %% [markdown]
# # Exercício 1
#
# O porto de South Louisiana, localizado ao longo de 54 milhas do Rio Mississippi, entre Nova Orleans e Baton Rouge, é o maior porto de carga a granel do mundo. A quantidade de toneladas de carga movimentadas por semana é normalmente distribuída com uma média de 4,5 milhões de toneladas de carga por semana e um desvio padrão de 0,82 milhão de toneladas.
# - a. Qual é a probabilidade de o porto manejar menos de 5 milh~çoes de toneladas de carga por semana?
# - b. Qual é a probabilidade de o porto movimentar 3 ou mais milhões de toneladas de carga por semana?
# - c. Qual é a probabilidade de o porto movimentar entre 3 e 4 milhões de toneladas de carga por semana?

# %%
media = 4.5
std = 0.82

# %%
# a. P(X < 5) = ?
norm.cdf(5, media, std)
# Out:
# 0.7289883061396114

# %%
# b. P(X >= 3)

norm.sf(3, media, std)
# Out:
# 0.9663202869206196

# %%
# c. P(3 < X < 4) = P(X < 4) - P(X < 3)
norm.cdf(4, media, std) - norm.cdf(3, media, std)
# Out:
# 0.23733198078100812

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercício 2
#
# Os prazos de duração de gravidez têm distribuição normal com média de 268 dias e desvio padrão de 15 dias. Se definirmos como prematura uma criança cujo período de gestação esteja nos 4% inferiores, determine o prazo de gestação que separa as crianças prematuras e não prematuras

# %%
prob = 0.04
media = 268
std = 15

# %%
norm.ppf(prob, media, std)
# Out:
# 241.73970893121745

# %% [markdown]
# # Exercício 3
# Os QI's tem distribuição normal com média 100 e desvio padrão 15. Definindo como gênio uma pessoal no 1% superior dos valores de QI, determine o valor que separa os gênios das pessoas comuns.

# %%
prob = 0.99 # 1 - 0.01
media = 100
std = 15

norm.ppf(prob, media, std)
# Out:
# 134.8952181106126
